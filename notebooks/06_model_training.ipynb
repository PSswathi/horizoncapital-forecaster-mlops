# %% [markdown]
# 1.	Load engineered train/validation/test feature splits from S3 (Parquet).
# 2.	Drop non-numeric columns (e.g., date, Datetime) and prepare XGBoost CSV format (target first for train/val, features only for test).
# 3.	Upload the generated CSV files to S3 under a training prefix.
# 4.	Train an XGBoost regression model in SageMaker using train + validation channels.
# 5.	Run Batch Transform on the test set to generate predictions and store outputs in S3.
# 6.	Capture and print the training job name and batch output S3 path for downstream evaluation/registry notebooks.

# %%
import os
from dotenv import load_dotenv

# Load .env from project root
load_dotenv()

ROLE_ARN = os.getenv("SAGEMAKER_ROLE_ARN")

if not ROLE_ARN:
    raise RuntimeError(
        "SAGEMAKER_ROLE_ARN not found.\n"
        "Ensure it is set in .env or environment variables."
    )

print("Using ROLE_ARN:", ROLE_ARN)
# Out:
# Using ROLE_ARN: arn:aws:iam::222634372778:role/service-role/AmazonSageMaker-ExecutionRole-20250603T080776

# %%
import os, sys, time
import boto3
import pandas as pd
import sagemaker
from sagemaker.inputs import TrainingInput
from time import gmtime, strftime

sys.path.append("..")
from config.config import AWS_REGION, BUCKET_NAME, S3_PREFIX, TARGET_COLUMN, MODEL_NAME, BUCKET_NAME, SAGEMAKER_ROLE_NAME

sess = sagemaker.Session()
region = sess.boto_region_name

bucket = BUCKET_NAME
prefix = "nfci-xgboost-regression"   # keep this notebook-specific prefix

print("Region:", region)
print("Bucket:", bucket)
print("Prefix:", prefix)
# Out:
# Region: us-east-1
# Bucket: nfci-forecasting-222634372778
# Prefix: nfci-xgboost-regression

# %%
import sagemaker
print("sagemaker version:", sagemaker.__version__)
# Out:
# sagemaker version: 2.256.1

# %%
# Load Parquet splits from S3

train_s3 = f"s3://{bucket}/{S3_PREFIX['train']}/features.parquet"
val_s3   = f"s3://{bucket}/{S3_PREFIX['validation']}/features.parquet"
test_s3  = f"s3://{bucket}/{S3_PREFIX['test']}/features.parquet"

df_train = pd.read_parquet(train_s3)
df_val   = pd.read_parquet(val_s3)
df_test  = pd.read_parquet(test_s3)

print(df_train.shape, df_val.shape, df_test.shape)
print("Target:", TARGET_COLUMN)
# Out:
# (6800, 80) (1100, 80) (1100, 80)
# Target: NFCI

# %%
# Drop non-numeric columns BEFORE generating CSVs
DROP_COLS = ["date", "Datetime"]

df_train = df_train.drop(columns=DROP_COLS, errors="ignore")
df_val   = df_val.drop(columns=DROP_COLS, errors="ignore")
df_test  = df_test.drop(columns=DROP_COLS, errors="ignore")

# %%
## Convert to CSV in XGBoost required format (target first)
def to_xgb_train_csv(df: pd.DataFrame, target: str, out_file: str):
    feature_cols = [c for c in df.columns if c != target]
    df_xgb = df[[target] + feature_cols].copy()
    df_xgb.to_csv(out_file, index=False, header=False)
    return out_file

def to_xgb_infer_csv(df: pd.DataFrame, target: str, out_file: str):
    feature_cols = [c for c in df.columns if c != target]
    df_xgb = df[feature_cols].copy()
    df_xgb.to_csv(out_file, index=False, header=False)
    return out_file

# %%
train_file = "train.csv"
val_file   = "validation.csv"
test_file  = "test.csv"

to_xgb_train_csv(df_train, TARGET_COLUMN, "train.csv")
to_xgb_train_csv(df_val,   TARGET_COLUMN, "validation.csv")
to_xgb_infer_csv(df_test,  TARGET_COLUMN, "test.csv")   

train_s3_uri = sess.upload_data(train_file, key_prefix=f"{prefix}/train")
val_s3_uri   = sess.upload_data(val_file,   key_prefix=f"{prefix}/validation")
test_s3_uri  = sess.upload_data(test_file,  key_prefix=f"{prefix}/test")

print("Uploaded train:", train_s3_uri)
print("Uploaded val:", val_s3_uri)
print("Uploaded test:", test_s3_uri)
# Out:
# Uploaded train: s3://sagemaker-us-east-1-222634372778/nfci-xgboost-regression/train/train.csv
# Uploaded val: s3://sagemaker-us-east-1-222634372778/nfci-xgboost-regression/validation/validation.csv
# Uploaded test: s3://sagemaker-us-east-1-222634372778/nfci-xgboost-regression/test/test.csv

# %%
import boto3
import json

iam_client = boto3.client("iam")

ROLE_NAME = ROLE_ARN.split("/")[-1] 
# BUCKET_NAME = "nfci-forecasting-222634372778"

policy_document = {
    "Version": "2012-10-17",
    "Statement": [
        {
            "Sid": "AllowListBucket",
            "Effect": "Allow",
            "Action": ["s3:ListBucket"],
            "Resource": f"arn:aws:s3:::{BUCKET_NAME}"
        },
        {
            "Sid": "AllowReadWriteObjects",
            "Effect": "Allow",
            "Action": [
                "s3:GetObject",
                "s3:PutObject",
                "s3:DeleteObject",
                "s3:AbortMultipartUpload",
                "s3:ListMultipartUploadParts",
                "s3:ListBucketMultipartUploads"
            ],
            "Resource": f"arn:aws:s3:::{BUCKET_NAME}/*"
        }
    ]
}

iam_client.put_role_policy(
    RoleName=ROLE_NAME,
    PolicyName="SageMakerS3TrainingArtifactsAccess",
    PolicyDocument=json.dumps(policy_document)
)

print("Inline policy attached successfully")
# Out:
# Inline policy attached successfully

# %%
# Training job

job_name = "xgb-nfci-reg-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())
output_location = f"s3://{bucket}/{prefix}/output/{job_name}"

image = sagemaker.image_uris.retrieve(
    framework="xgboost", region=region, version="1.7-1"
)

sm_estimator = sagemaker.estimator.Estimator(
    image_uri=image,
    role=ROLE_ARN,
    instance_count=1,
    instance_type="ml.m5.xlarge",
    volume_size=50,
    input_mode="File",
    output_path=output_location,
    sagemaker_session=sess,
)

sm_estimator.set_hyperparameters(
    objective="reg:squarederror",
    eval_metric="rmse",
    max_depth=5,
    eta=0.1,
    subsample=0.8,
    colsample_bytree=0.8,
    num_round=300,
)

train_data = TrainingInput(train_s3_uri, content_type="text/csv")
validation_data = TrainingInput(val_s3_uri, content_type="text/csv")

sm_estimator.fit({"train": train_data, "validation": validation_data}, job_name=job_name, logs=True)
# Out:
# INFO:sagemaker:Creating training-job with name: xgb-nfci-reg-2026-02-02-07-51-47
# 2026-02-02 07:49:09 Starting - Starting the training job...
# 2026-02-02 07:49:26 Starting - Preparing the instances for training...
# 2026-02-02 07:50:12 Downloading - Downloading the training image......
# 2026-02-02 07:51:03 Training - Training image download completed. Training in progress../miniconda3/lib/python3.9/site-packages/sagemaker_containers/_server.py:22: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# [2026-02-02 07:51:14.338 ip-10-0-167-41.ec2.internal:7 INFO utils.py:28] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2026-02-02 07:51:14.399 ip-10-0-167-41.ec2.internal:7 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2026-02-02:07:51:14:INFO] Imported framework sagemaker_xgboost_container.training
# [2026-02-02:07:51:14:INFO] Failed to parse hyperparameter eval_metric value rmse to Json.
# Returning the value itself
# [2026-02-02:07:51:14:INFO] Failed to parse hyperparameter objective value reg:squarederror to Json.
# Returning the value itself
# [2026-02-02:07:51:14:INFO] No GPUs detected (normal if no gpus installed)
# [2026-02-02:07:51:14:INFO] Running XGBoost Sagemaker in algorithm mode
# [2026-02-02:07:51:14:INFO] Determined 0 GPU(s) available on the instance.
# [2026-02-02:07:51:14:INFO] Determined delimiter of CSV input is ','
# [2026-02-02:07:51:14:INFO] Determined delimiter of CSV input is ','
# [2026-02-02:07:51:14:INFO] File path /opt/ml/input/data/train of input files
# [2026-02-02:07:51:14:INFO] Making smlinks from folder /opt/ml/input/data/train to folder /tmp/sagemaker_xgboost_input_data
# [2026-02-02:07:51:14:INFO] creating symlink between Path /opt/ml/input/data/train/train.csv and destination /tmp/sagemaker_xgboost_input_data/train.csv5465860836129109909
# [2026-02-02:07:51:14:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2026-02-02:07:51:14:INFO] Determined delimiter of CSV input is ','
# [2026-02-02:07:51:14:INFO] File path /opt/ml/input/data/validation of input files
# [2026-02-02:07:51:14:INFO] Making smlinks from folder /opt/ml/input/data/validation to folder /tmp/sagemaker_xgboost_input_data
# [2026-02-02:07:51:14:INFO] creating symlink between Path /opt/ml/input/data/validation/validation.csv and destination /tmp/sagemaker_xgboost_input_data/validation.csv-1437255461249320318
# [2026-02-02:07:51:14:INFO] files path: /tmp/sagemaker_xgboost_input_data
# [2026-02-02:07:51:14:INFO] Determined delimiter of CSV input is ','
# [2026-02-02:07:51:14:INFO] Single node training.
# [2026-02-02:07:51:14:INFO] Train matrix has 6800 rows and 78 columns
# [2026-02-02:07:51:14:INFO] Validation matrix has 1100 rows
# [2026-02-02 07:51:14.791 ip-10-0-167-41.ec2.internal:7 INFO json_config.py:92] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2026-02-02 07:51:14.792 ip-10-0-167-41.ec2.internal:7 INFO hook.py:206] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2026-02-02 07:51:14.792 ip-10-0-167-41.ec2.internal:7 INFO hook.py:259] Saving to /opt/ml/output/tensors
# [2026-02-02 07:51:14.792 ip-10-0-167-41.ec2.internal:7 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2026-02-02:07:51:14:INFO] Debug hook created from config
# /miniconda3/lib/python3.9/site-packages/xgboost/training.py:39: UserWarning: `feval` is deprecated, use `custom_metric` instead.  They have different behavior when custom objective is also used.See https://xgboost.readthedocs.io/en/latest/tutorials/custom_metric_obj.html for details on the `custom_metric`.
#   warnings.warn(
# [0]#011train-rmse:0.92704#011validation-rmse:0.89504
# [2026-02-02 07:51:14.876 ip-10-0-167-41.ec2.internal:7 INFO hook.py:427] Monitoring the collections: metrics
# [2026-02-02 07:51:14.881 ip-10-0-167-41.ec2.internal:7 INFO hook.py:491] Hook is writing from the hook with pid: 7
# [1]#011train-rmse:0.83493#011validation-rmse:0.81336
# [2]#011train-rmse:0.75205#011validation-rmse:0.73563
# [3]#011train-rmse:0.67734#011validation-rmse:0.66616
# [4]#011train-rmse:0.61015#011validation-rmse:0.60286
# [5]#011train-rmse:0.54961#011validation-rmse:0.54670
# [6]#011train-rmse:0.49510#011validation-rmse:0.49681
# [7]#011train-rmse:0.44603#011validation-rmse:0.44581
# [8]#011train-rmse:0.40182#011validation-rmse:0.40363
# [9]#011train-rmse:0.36199#011validation-rmse:0.36650
# [10]#011train-rmse:0.32613#011validation-rmse:0.33698
# [11]#011train-rmse:0.29381#011validation-rmse:0.30173
# [12]#011train-rmse:0.26476#011validation-rmse:0.27548
# [13]#011train-rmse:0.23860#011validation-rmse:0.25054
# [14]#011train-rmse:0.21499#011validation-rmse:0.23053
# [15]#011train-rmse:0.19375#011validation-rmse:0.20779
# [16]#011train-rmse:0.17462#011validation-rmse:0.18892
# [17]#011train-rmse:0.15744#011validation-rmse:0.17340
# [18]#011train-rmse:0.14191#011validation-rmse:0.15708
# [19]#011train-rmse:0.12793#011validation-rmse:0.14241
# [20]#011train-rmse:0.11534#011validation-rmse:0.12983
# [21]#011train-rmse:0.10402#011validation-rmse:0.11870
# [22]#011train-rmse:0.09385#011validation-rmse:0.10846
# [23]#011train-rmse:0.08467#011validation-rmse:0.10040
# [24]#011train-rmse:0.07638#011validation-rmse:0.09181
# [25]#011train-rmse:0.06897#011validation-rmse:0.08523
# [26]#011train-rmse:0.06228#011validation-rmse:0.07973
# [27]#011train-rmse:0.05627#011validation-rmse:0.07593
# [28]#011train-rmse:0.05089#011validation-rmse:0.07165
# [29]#011train-rmse:0.04601#011validation-rmse:0.06803
# [30]#011train-rmse:0.04160#011validation-rmse:0.06506
# [31]#011train-rmse:0.03766#011validation-rmse:0.06146
# [32]#011train-rmse:0.03409#011validation-rmse:0.05887
# [33]#011train-rmse:0.03091#011validation-rmse:0.05695
# [34]#011train-rmse:0.02809#011validation-rmse:0.05495
# [35]#011train-rmse:0.02552#011validation-rmse:0.05313
# [36]#011train-rmse:0.02320#011validation-rmse:0.05201
# [37]#011train-rmse:0.02111#011validation-rmse:0.05051
# [38]#011train-rmse:0.01922#011validation-rmse:0.04916
# [39]#011train-rmse:0.01758#011validation-rmse:0.04805
# [40]#011train-rmse:0.01607#011validation-rmse:0.04675
# [41]#011train-rmse:0.01475#011validation-rmse:0.04629
# [42]#011train-rmse:0.01352#011validation-rmse:0.04546
# [43]#011train-rmse:0.01238#011validation-rmse:0.04533
# [44]#011train-rmse:0.01138#011validation-rmse:0.04485
# [45]#011train-rmse:0.01054#011validation-rmse:0.04428
# [46]#011train-rmse:0.00966#011validation-rmse:0.04433
# [47]#011train-rmse:0.00893#011validation-rmse:0.04402
# [48]#011train-rmse:0.00821#011validation-rmse:0.04361
# [49]#011train-rmse:0.00763#011validation-rmse:0.04338
# [50]#011train-rmse:0.00707#011validation-rmse:0.04317
# [51]#011train-rmse:0.00651#011validation-rmse:0.04296
# [52]#011train-rmse:0.00610#011validation-rmse:0.04262
# [53]#011train-rmse:0.00576#011validation-rmse:0.04232
# [54]#011train-rmse:0.00546#011validation-rmse:0.04224
# [55]#011train-rmse:0.00513#011validation-rmse:0.04222
# [56]#011train-rmse:0.00478#011validation-rmse:0.04193
# [57]#011train-rmse:0.00452#011validation-rmse:0.04181
# [58]#011train-rmse:0.00431#011validation-rmse:0.04176
# [59]#011train-rmse:0.00406#011validation-rmse:0.04180
# [60]#011train-rmse:0.00385#011validation-rmse:0.04163
# [61]#011train-rmse:0.00368#011validation-rmse:0.04136
# [62]#011train-rmse:0.00349#011validation-rmse:0.04126
# [63]#011train-rmse:0.00336#011validation-rmse:0.04117
# [64]#011train-rmse:0.00321#011validation-rmse:0.04104
# [65]#011train-rmse:0.00310#011validation-rmse:0.04096
# [66]#011train-rmse:0.00299#011validation-rmse:0.04092
# [67]#011train-rmse:0.00290#011validation-rmse:0.04093
# [68]#011train-rmse:0.00281#011validation-rmse:0.04088
# [69]#011train-rmse:0.00269#011validation-rmse:0.04095
# [70]#011train-rmse:0.00261#011validation-rmse:0.04087
# [71]#011train-rmse:0.00254#011validation-rmse:0.04072
# [72]#011train-rmse:0.00238#011validation-rmse:0.04065
# [73]#011train-rmse:0.00226#011validation-rmse:0.04074
# [74]#011train-rmse:0.00218#011validation-rmse:0.04083
# [75]#011train-rmse:0.00209#011validation-rmse:0.04088
# [76]#011train-rmse:0.00201#011validation-rmse:0.04086
# [77]#011train-rmse:0.00191#011validation-rmse:0.04088
# [78]#011train-rmse:0.00178#011validation-rmse:0.04091
# [79]#011train-rmse:0.00171#011validation-rmse:0.04091
# [80]#011train-rmse:0.00166#011validation-rmse:0.04096
# [81]#011train-rmse:0.00159#011validation-rmse:0.04098
# [82]#011train-rmse:0.00151#011validation-rmse:0.04085
# [83]#011train-rmse:0.00144#011validation-rmse:0.04086
# [84]#011train-rmse:0.00138#011validation-rmse:0.04086
# [85]#011train-rmse:0.00134#011validation-rmse:0.04088
# [86]#011train-rmse:0.00131#011validation-rmse:0.04089
# [87]#011train-rmse:0.00126#011validation-rmse:0.04089
# [88]#011train-rmse:0.00122#011validation-rmse:0.04089
# [89]#011train-rmse:0.00118#011validation-rmse:0.04089
# [90]#011train-rmse:0.00116#011validation-rmse:0.04088
# [91]#011train-rmse:0.00113#011validation-rmse:0.04085
# [92]#011train-rmse:0.00109#011validation-rmse:0.04084
# [93]#011train-rmse:0.00105#011validation-rmse:0.04091
# [94]#011train-rmse:0.00103#011validation-rmse:0.04095
# [95]#011train-rmse:0.00100#011validation-rmse:0.04095
# [96]#011train-rmse:0.00097#011validation-rmse:0.04099
# [97]#011train-rmse:0.00093#011validation-rmse:0.04100
# [98]#011train-rmse:0.00091#011validation-rmse:0.04103
# [99]#011train-rmse:0.00089#011validation-rmse:0.04102
# [100]#011train-rmse:0.00087#011validation-rmse:0.04097
# [101]#011train-rmse:0.00085#011validation-rmse:0.04097
# [102]#011train-rmse:0.00083#011validation-rmse:0.04096
# [103]#011train-rmse:0.00082#011validation-rmse:0.04096
# [104]#011train-rmse:0.00079#011validation-rmse:0.04096
# [105]#011train-rmse:0.00078#011validation-rmse:0.04100
# [106]#011train-rmse:0.00075#011validation-rmse:0.04098
# [107]#011train-rmse:0.00073#011validation-rmse:0.04098
# [108]#011train-rmse:0.00071#011validation-rmse:0.04101
# [109]#011train-rmse:0.00070#011validation-rmse:0.04102
# [110]#011train-rmse:0.00069#011validation-rmse:0.04104
# [111]#011train-rmse:0.00068#011validation-rmse:0.04100
# [112]#011train-rmse:0.00066#011validation-rmse:0.04102
# [113]#011train-rmse:0.00065#011validation-rmse:0.04101
# [114]#011train-rmse:0.00064#011validation-rmse:0.04102
# [115]#011train-rmse:0.00063#011validation-rmse:0.04103
# [116]#011train-rmse:0.00061#011validation-rmse:0.04104
# [117]#011train-rmse:0.00060#011validation-rmse:0.04104
# [118]#011train-rmse:0.00059#011validation-rmse:0.04104
# [119]#011train-rmse:0.00059#011validation-rmse:0.04104
# [120]#011train-rmse:0.00058#011validation-rmse:0.04104
# [121]#011train-rmse:0.00057#011validation-rmse:0.04104
# [122]#011train-rmse:0.00055#011validation-rmse:0.04103
# [123]#011train-rmse:0.00054#011validation-rmse:0.04103
# [124]#011train-rmse:0.00052#011validation-rmse:0.04101
# [125]#011train-rmse:0.00051#011validation-rmse:0.04102
# [126]#011train-rmse:0.00050#011validation-rmse:0.04104
# [127]#011train-rmse:0.00049#011validation-rmse:0.04103
# [128]#011train-rmse:0.00048#011validation-rmse:0.04103
# [129]#011train-rmse:0.00047#011validation-rmse:0.04106
# [130]#011train-rmse:0.00045#011validation-rmse:0.04106
# [131]#011train-rmse:0.00045#011validation-rmse:0.04106
# [132]#011train-rmse:0.00044#011validation-rmse:0.04108
# [133]#011train-rmse:0.00043#011validation-rmse:0.04108
# [134]#011train-rmse:0.00042#011validation-rmse:0.04110
# [135]#011train-rmse:0.00041#011validation-rmse:0.04110
# [136]#011train-rmse:0.00040#011validation-rmse:0.04109
# [137]#011train-rmse:0.00039#011validation-rmse:0.04109
# [138]#011train-rmse:0.00038#011validation-rmse:0.04110
# [139]#011train-rmse:0.00038#011validation-rmse:0.04110
# [140]#011train-rmse:0.00037#011validation-rmse:0.04110
# [141]#011train-rmse:0.00036#011validation-rmse:0.04112
# [142]#011train-rmse:0.00035#011validation-rmse:0.04113
# [143]#011train-rmse:0.00034#011validation-rmse:0.04112
# [144]#011train-rmse:0.00033#011validation-rmse:0.04110
# [145]#011train-rmse:0.00032#011validation-rmse:0.04112
# [146]#011train-rmse:0.00031#011validation-rmse:0.04112
# [147]#011train-rmse:0.00030#011validation-rmse:0.04112
# [148]#011train-rmse:0.00030#011validation-rmse:0.04112
# [149]#011train-rmse:0.00029#011validation-rmse:0.04113
# [150]#011train-rmse:0.00028#011validation-rmse:0.04112
# [151]#011train-rmse:0.00028#011validation-rmse:0.04113
# [152]#011train-rmse:0.00028#011validation-rmse:0.04113
# [153]#011train-rmse:0.00027#011validation-rmse:0.04113
# [154]#011train-rmse:0.00026#011validation-rmse:0.04113
# [155]#011train-rmse:0.00026#011validation-rmse:0.04113
# [156]#011train-rmse:0.00025#011validation-rmse:0.04112
# [157]#011train-rmse:0.00025#011validation-rmse:0.04112
# [158]#011train-rmse:0.00024#011validation-rmse:0.04112
# [159]#011train-rmse:0.00023#011validation-rmse:0.04112
# [160]#011train-rmse:0.00023#011validation-rmse:0.04112
# [161]#011train-rmse:0.00022#011validation-rmse:0.04113
# [162]#011train-rmse:0.00022#011validation-rmse:0.04113
# [163]#011train-rmse:0.00021#011validation-rmse:0.04113
# [164]#011train-rmse:0.00021#011validation-rmse:0.04113
# [165]#011train-rmse:0.00021#011validation-rmse:0.04113
# [166]#011train-rmse:0.00020#011validation-rmse:0.04113
# [167]#011train-rmse:0.00020#011validation-rmse:0.04113
# [168]#011train-rmse:0.00019#011validation-rmse:0.04113
# [169]#011train-rmse:0.00019#011validation-rmse:0.04113
# [170]#011train-rmse:0.00019#011validation-rmse:0.04114
# [171]#011train-rmse:0.00018#011validation-rmse:0.04114
# [172]#011train-rmse:0.00018#011validation-rmse:0.04115
# [173]#011train-rmse:0.00017#011validation-rmse:0.04116
# [174]#011train-rmse:0.00017#011validation-rmse:0.04117
# [175]#011train-rmse:0.00016#011validation-rmse:0.04117
# [176]#011train-rmse:0.00016#011validation-rmse:0.04117
# [177]#011train-rmse:0.00016#011validation-rmse:0.04117
# [178]#011train-rmse:0.00015#011validation-rmse:0.04117
# [179]#011train-rmse:0.00015#011validation-rmse:0.04117
# [180]#011train-rmse:0.00015#011validation-rmse:0.04117
# [181]#011train-rmse:0.00015#011validation-rmse:0.04116
# [182]#011train-rmse:0.00014#011validation-rmse:0.04116
# [183]#011train-rmse:0.00014#011validation-rmse:0.04117
# [184]#011train-rmse:0.00014#011validation-rmse:0.04117
# [185]#011train-rmse:0.00014#011validation-rmse:0.04117
# [186]#011train-rmse:0.00013#011validation-rmse:0.04117
# [187]#011train-rmse:0.00013#011validation-rmse:0.04118
# [188]#011train-rmse:0.00013#011validation-rmse:0.04118
# [189]#011train-rmse:0.00012#011validation-rmse:0.04118
# [190]#011train-rmse:0.00012#011validation-rmse:0.04117
# [191]#011train-rmse:0.00012#011validation-rmse:0.04118
# [192]#011train-rmse:0.00012#011validation-rmse:0.04118
# [193]#011train-rmse:0.00012#011validation-rmse:0.04118
# [194]#011train-rmse:0.00011#011validation-rmse:0.04118
# [195]#011train-rmse:0.00011#011validation-rmse:0.04118
# [196]#011train-rmse:0.00011#011validation-rmse:0.04118
# [197]#011train-rmse:0.00011#011validation-rmse:0.04118
# [198]#011train-rmse:0.00011#011validation-rmse:0.04118
# [199]#011train-rmse:0.00011#011validation-rmse:0.04118
# [200]#011train-rmse:0.00011#011validation-rmse:0.04118
# [201]#011train-rmse:0.00011#011validation-rmse:0.04118
# [202]#011train-rmse:0.00011#011validation-rmse:0.04118
# [203]#011train-rmse:0.00011#011validation-rmse:0.04118
# [204]#011train-rmse:0.00011#011validation-rmse:0.04118
# [205]#011train-rmse:0.00011#011validation-rmse:0.04118
# [206]#011train-rmse:0.00011#011validation-rmse:0.04118
# [207]#011train-rmse:0.00011#011validation-rmse:0.04118
# [208]#011train-rmse:0.00011#011validation-rmse:0.04118
# [209]#011train-rmse:0.00011#011validation-rmse:0.04118
# [210]#011train-rmse:0.00011#011validation-rmse:0.04118
# [211]#011train-rmse:0.00011#011validation-rmse:0.04118
# [212]#011train-rmse:0.00011#011validation-rmse:0.04118
# [213]#011train-rmse:0.00011#011validation-rmse:0.04118
# [214]#011train-rmse:0.00011#011validation-rmse:0.04118
# [215]#011train-rmse:0.00011#011validation-rmse:0.04118
# [216]#011train-rmse:0.00011#011validation-rmse:0.04118
# [217]#011train-rmse:0.00011#011validation-rmse:0.04118
# [218]#011train-rmse:0.00011#011validation-rmse:0.04118
# [219]#011train-rmse:0.00011#011validation-rmse:0.04118
# [220]#011train-rmse:0.00011#011validation-rmse:0.04118
# [221]#011train-rmse:0.00011#011validation-rmse:0.04118
# [222]#011train-rmse:0.00011#011validation-rmse:0.04118
# [223]#011train-rmse:0.00011#011validation-rmse:0.04118
# [224]#011train-rmse:0.00011#011validation-rmse:0.04118
# [225]#011train-rmse:0.00011#011validation-rmse:0.04118
# [226]#011train-rmse:0.00011#011validation-rmse:0.04118
# [227]#011train-rmse:0.00011#011validation-rmse:0.04118
# [228]#011train-rmse:0.00011#011validation-rmse:0.04118
# [229]#011train-rmse:0.00011#011validation-rmse:0.04118
# [230]#011train-rmse:0.00011#011validation-rmse:0.04118
# [231]#011train-rmse:0.00011#011validation-rmse:0.04118
# [232]#011train-rmse:0.00011#011validation-rmse:0.04118
# [233]#011train-rmse:0.00011#011validation-rmse:0.04118
# [234]#011train-rmse:0.00011#011validation-rmse:0.04118
# [235]#011train-rmse:0.00011#011validation-rmse:0.04118
# [236]#011train-rmse:0.00011#011validation-rmse:0.04118
# [237]#011train-rmse:0.00011#011validation-rmse:0.04118
# [238]#011train-rmse:0.00011#011validation-rmse:0.04118
# [239]#011train-rmse:0.00011#011validation-rmse:0.04118
# [240]#011train-rmse:0.00011#011validation-rmse:0.04118
# [241]#011train-rmse:0.00011#011validation-rmse:0.04118
# [242]#011train-rmse:0.00011#011validation-rmse:0.04118
# [243]#011train-rmse:0.00011#011validation-rmse:0.04118
# [244]#011train-rmse:0.00011#011validation-rmse:0.04118
# [245]#011train-rmse:0.00011#011validation-rmse:0.04118
# [246]#011train-rmse:0.00011#011validation-rmse:0.04118
# [247]#011train-rmse:0.00011#011validation-rmse:0.04118
# [248]#011train-rmse:0.00011#011validation-rmse:0.04118
# [249]#011train-rmse:0.00011#011validation-rmse:0.04118
# [250]#011train-rmse:0.00011#011validation-rmse:0.04118
# [251]#011train-rmse:0.00011#011validation-rmse:0.04118
# [252]#011train-rmse:0.00011#011validation-rmse:0.04118
# [253]#011train-rmse:0.00011#011validation-rmse:0.04118
# [254]#011train-rmse:0.00011#011validation-rmse:0.04118
# [255]#011train-rmse:0.00011#011validation-rmse:0.04118
# [256]#011train-rmse:0.00011#011validation-rmse:0.04118
# [257]#011train-rmse:0.00011#011validation-rmse:0.04118
# [258]#011train-rmse:0.00011#011validation-rmse:0.04118
# [259]#011train-rmse:0.00011#011validation-rmse:0.04118
# [260]#011train-rmse:0.00011#011validation-rmse:0.04118
# [261]#011train-rmse:0.00011#011validation-rmse:0.04118
# [262]#011train-rmse:0.00011#011validation-rmse:0.04118
# [263]#011train-rmse:0.00011#011validation-rmse:0.04118
# [264]#011train-rmse:0.00011#011validation-rmse:0.04118
# [265]#011train-rmse:0.00011#011validation-rmse:0.04118
# [266]#011train-rmse:0.00011#011validation-rmse:0.04118
# [267]#011train-rmse:0.00011#011validation-rmse:0.04118
# [268]#011train-rmse:0.00011#011validation-rmse:0.04118
# [269]#011train-rmse:0.00011#011validation-rmse:0.04118
# [270]#011train-rmse:0.00011#011validation-rmse:0.04118
# [271]#011train-rmse:0.00011#011validation-rmse:0.04118
# [272]#011train-rmse:0.00011#011validation-rmse:0.04118
# [273]#011train-rmse:0.00011#011validation-rmse:0.04118
# [274]#011train-rmse:0.00011#011validation-rmse:0.04118
# [275]#011train-rmse:0.00011#011validation-rmse:0.04118
# [276]#011train-rmse:0.00011#011validation-rmse:0.04118
# [277]#011train-rmse:0.00011#011validation-rmse:0.04118
# [278]#011train-rmse:0.00011#011validation-rmse:0.04118
# [279]#011train-rmse:0.00011#011validation-rmse:0.04118
# [280]#011train-rmse:0.00011#011validation-rmse:0.04118
# [281]#011train-rmse:0.00011#011validation-rmse:0.04118
# [282]#011train-rmse:0.00011#011validation-rmse:0.04118
# [283]#011train-rmse:0.00011#011validation-rmse:0.04118
# [284]#011train-rmse:0.00011#011validation-rmse:0.04118
# [285]#011train-rmse:0.00011#011validation-rmse:0.04118
# [286]#011train-rmse:0.00011#011validation-rmse:0.04118
# [287]#011train-rmse:0.00011#011validation-rmse:0.04118
# [288]#011train-rmse:0.00010#011validation-rmse:0.04119
# [289]#011train-rmse:0.00010#011validation-rmse:0.04119
# [290]#011train-rmse:0.00010#011validation-rmse:0.04119
# [291]#011train-rmse:0.00010#011validation-rmse:0.04119
# [292]#011train-rmse:0.00010#011validation-rmse:0.04119
# [293]#011train-rmse:0.00010#011validation-rmse:0.04119
# [294]#011train-rmse:0.00010#011validation-rmse:0.04119
# [295]#011train-rmse:0.00010#011validation-rmse:0.04119
# [296]#011train-rmse:0.00010#011validation-rmse:0.04119
# [297]#011train-rmse:0.00010#011validation-rmse:0.04119
# [298]#011train-rmse:0.00010#011validation-rmse:0.04119
# [299]#011train-rmse:0.00010#011validation-rmse:0.04119
#
# 2026-02-02 07:51:31 Uploading - Uploading generated training model
# 2026-02-02 07:51:31 Completed - Training job completed
# Training seconds: 104
# Billable seconds: 104

# %%
# Take the trained model artifact from sm_estimator and Prepare to write predictions to the given S3 path
transformer = sm_estimator.transformer(
    instance_count=1,
    instance_type="ml.m5.xlarge",
    output_path=f"s3://{bucket}/{prefix}/batch-output/{job_name}",
)

transformer.transform(test_s3_uri, content_type="text/csv", split_type="Line")
transformer.wait()
print("Batch output:", transformer.output_path)
local_test_csv = "test.csv"
# Out:
# INFO:sagemaker:Creating model with name: sagemaker-xgboost-2026-02-02-07-54-45-582
# INFO:sagemaker:Creating transform job with name: sagemaker-xgboost-2026-02-02-07-54-46-259
# ............................./miniconda3/lib/python3.9/site-packages/sagemaker_containers/_server.py:22: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# [2026-02-02:07:57:01:INFO] No GPUs detected (normal if no gpus installed)
# [2026-02-02:07:57:01:INFO] No GPUs detected (normal if no gpus installed)
# [2026-02-02:07:57:01:INFO] nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
# worker_rlimit_nofile 4096;
# events {
#   worker_connections 2048;
# }
# /miniconda3/lib/python3.9/site-packages/sagemaker_containers/_server.py:22: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# [2026-02-02:07:57:01:INFO] No GPUs detected (normal if no gpus installed)
# [2026-02-02:07:57:01:INFO] No GPUs detected (normal if no gpus installed)
# [2026-02-02:07:57:01:INFO] nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
# worker_rlimit_nofile 4096;
# events {
#   worker_connections 2048;
# }
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#     keepalive_timeout 3;
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#     location / {
#       return 404 "{}";
#     }
#   }
# }
# [2026-02-02 07:57:01 +0000] [18] [INFO] Starting gunicorn 23.0.0
# [2026-02-02 07:57:01 +0000] [18] [INFO] Listening at: unix:/tmp/gunicorn.sock (18)
# [2026-02-02 07:57:01 +0000] [18] [INFO] Using worker: gevent
# [2026-02-02 07:57:01 +0000] [23] [INFO] Booting worker with pid: 23
# [2026-02-02 07:57:01 +0000] [24] [INFO] Booting worker with pid: 24
# [2026-02-02 07:57:02 +0000] [25] [INFO] Booting worker with pid: 25
# [2026-02-02 07:57:02 +0000] [26] [INFO] Booting worker with pid: 26
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#     keepalive_timeout 3;
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#     location / {
#       return 404 "{}";
#     }
#   }
# }
# [2026-02-02 07:57:01 +0000] [18] [INFO] Starting gunicorn 23.0.0
# [2026-02-02 07:57:01 +0000] [18] [INFO] Listening at: unix:/tmp/gunicorn.sock (18)
# [2026-02-02 07:57:01 +0000] [18] [INFO] Using worker: gevent
# [2026-02-02 07:57:01 +0000] [23] [INFO] Booting worker with pid: 23
# [2026-02-02 07:57:01 +0000] [24] [INFO] Booting worker with pid: 24
# [2026-02-02 07:57:02 +0000] [25] [INFO] Booting worker with pid: 25
# [2026-02-02 07:57:02 +0000] [26] [INFO] Booting worker with pid: 26
# /miniconda3/lib/python3.9/site-packages/sagemaker_containers/_server.py:22: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /miniconda3/lib/python3.9/site-packages/sagemaker_containers/_server.py:22: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /miniconda3/lib/python3.9/site-packages/sagemaker_containers/_server.py:22: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /miniconda3/lib/python3.9/site-packages/sagemaker_containers/_server.py:22: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /miniconda3/lib/python3.9/site-packages/sagemaker_containers/_server.py:22: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /miniconda3/lib/python3.9/site-packages/sagemaker_containers/_server.py:22: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /miniconda3/lib/python3.9/site-packages/sagemaker_containers/_server.py:22: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /miniconda3/lib/python3.9/site-packages/sagemaker_containers/_server.py:22: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# [2026-02-02:07:57:04:INFO] No GPUs detected (normal if no gpus installed)
# [2026-02-02:07:57:04:INFO] Loading the model from /opt/ml/model/xgboost-model
# [2026-02-02:07:57:04:INFO] Model objective : reg:squarederror
# [2026-02-02:07:57:04:INFO] No GPUs detected (normal if no gpus installed)
# [2026-02-02:07:57:04:INFO] Loading the model from /opt/ml/model/xgboost-model
# [2026-02-02:07:57:04:INFO] Model objective : reg:squarederror
# [2026-02-02:07:57:04:INFO] No GPUs detected (normal if no gpus installed)
# [2026-02-02:07:57:04:INFO] Loading the model from /opt/ml/model/xgboost-model
# [2026-02-02:07:57:04:INFO] Model objective : reg:squarederror
# [2026-02-02:07:57:04:INFO] No GPUs detected (normal if no gpus installed)
# [2026-02-02:07:57:04:INFO] No GPUs detected (normal if no gpus installed)
# [2026-02-02:07:57:04:INFO] Loading the model from /opt/ml/model/xgboost-model
# [2026-02-02:07:57:04:INFO] Model objective : reg:squarederror
# [2026-02-02:07:57:04:INFO] No GPUs detected (normal if no gpus installed)
# [2026-02-02:07:57:04:INFO] Loading the model from /opt/ml/model/xgboost-model
# [2026-02-02:07:57:04:INFO] Model objective : reg:squarederror
# [2026-02-02:07:57:04:INFO] No GPUs detected (normal if no gpus installed)
# [2026-02-02:07:57:04:INFO] Loading the model from /opt/ml/model/xgboost-model
# [2026-02-02:07:57:04:INFO] Model objective : reg:squarederror
# [2026-02-02:07:57:04:INFO] No GPUs detected (normal if no gpus installed)
# [2026-02-02:07:57:04:INFO] Loading the model from /opt/ml/model/xgboost-model
# [2026-02-02:07:57:04:INFO] Model objective : reg:squarederror
# [2026-02-02:07:57:04:INFO] Loading the model from /opt/ml/model/xgboost-model
# [2026-02-02:07:57:04:INFO] Model objective : reg:squarederror
# [2026-02-02:07:57:07:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [02/Feb/2026:07:57:07 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# [2026-02-02:07:57:07:INFO] No GPUs detected (normal if no gpus installed)
# [2026-02-02:07:57:07:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [02/Feb/2026:07:57:07 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# [2026-02-02:07:57:07:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [02/Feb/2026:07:57:07 +0000] "GET /execution-parameters HTTP/1.1" 200 84 "-" "Go-http-client/1.1"
# [2026-02-02:07:57:07:INFO] No GPUs detected (normal if no gpus installed)
# [2026-02-02:07:57:07:INFO] Determined delimiter of CSV input is ','
# /miniconda3/lib/python3.9/site-packages/xgboost/core.py:122: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# 169.254.255.130 - - [02/Feb/2026:07:57:07 +0000] "POST /invocations HTTP/1.1" 200 22050 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [02/Feb/2026:07:57:07 +0000] "GET /execution-parameters HTTP/1.1" 200 84 "-" "Go-http-client/1.1"
# [2026-02-02:07:57:07:INFO] No GPUs detected (normal if no gpus installed)
# [2026-02-02:07:57:07:INFO] Determined delimiter of CSV input is ','
# /miniconda3/lib/python3.9/site-packages/xgboost/core.py:122: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# 169.254.255.130 - - [02/Feb/2026:07:57:07 +0000] "POST /invocations HTTP/1.1" 200 22050 "-" "Go-http-client/1.1"
# 2026-02-02T07:57:07.311:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
#
# /miniconda3/lib/python3.9/site-packages/sagemaker_containers/_server.py:22: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# [2026-02-02:07:57:01:INFO] No GPUs detected (normal if no gpus installed)
# [2026-02-02:07:57:01:INFO] No GPUs detected (normal if no gpus installed)
# [2026-02-02:07:57:01:INFO] nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
# worker_rlimit_nofile 4096;
# events {
#   worker_connections 2048;
# }
# /miniconda3/lib/python3.9/site-packages/sagemaker_containers/_server.py:22: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# [2026-02-02:07:57:01:INFO] No GPUs detected (normal if no gpus installed)
# [2026-02-02:07:57:01:INFO] No GPUs detected (normal if no gpus installed)
# [2026-02-02:07:57:01:INFO] nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
# worker_rlimit_nofile 4096;
# events {
#   worker_connections 2048;
# }
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#     keepalive_timeout 3;
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#     location / {
#       return 404 "{}";
#     }
#   }
# }
# [2026-02-02 07:57:01 +0000] [18] [INFO] Starting gunicorn 23.0.0
# [2026-02-02 07:57:01 +0000] [18] [INFO] Listening at: unix:/tmp/gunicorn.sock (18)
# [2026-02-02 07:57:01 +0000] [18] [INFO] Using worker: gevent
# [2026-02-02 07:57:01 +0000] [23] [INFO] Booting worker with pid: 23
# [2026-02-02 07:57:01 +0000] [24] [INFO] Booting worker with pid: 24
# [2026-02-02 07:57:02 +0000] [25] [INFO] Booting worker with pid: 25
# [2026-02-02 07:57:02 +0000] [26] [INFO] Booting worker with pid: 26
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#     keepalive_timeout 3;
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#     location / {
#       return 404 "{}";
#     }
#   }
# }
# [2026-02-02 07:57:01 +0000] [18] [INFO] Starting gunicorn 23.0.0
# [2026-02-02 07:57:01 +0000] [18] [INFO] Listening at: unix:/tmp/gunicorn.sock (18)
# [2026-02-02 07:57:01 +0000] [18] [INFO] Using worker: gevent
# [2026-02-02 07:57:01 +0000] [23] [INFO] Booting worker with pid: 23
# [2026-02-02 07:57:01 +0000] [24] [INFO] Booting worker with pid: 24
# [2026-02-02 07:57:02 +0000] [25] [INFO] Booting worker with pid: 25
# [2026-02-02 07:57:02 +0000] [26] [INFO] Booting worker with pid: 26
# /miniconda3/lib/python3.9/site-packages/sagemaker_containers/_server.py:22: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /miniconda3/lib/python3.9/site-packages/sagemaker_containers/_server.py:22: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /miniconda3/lib/python3.9/site-packages/sagemaker_containers/_server.py:22: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /miniconda3/lib/python3.9/site-packages/sagemaker_containers/_server.py:22: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /miniconda3/lib/python3.9/site-packages/sagemaker_containers/_server.py:22: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /miniconda3/lib/python3.9/site-packages/sagemaker_containers/_server.py:22: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /miniconda3/lib/python3.9/site-packages/sagemaker_containers/_server.py:22: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /miniconda3/lib/python3.9/site-packages/sagemaker_containers/_server.py:22: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# [2026-02-02:07:57:04:INFO] No GPUs detected (normal if no gpus installed)
# [2026-02-02:07:57:04:INFO] Loading the model from /opt/ml/model/xgboost-model
# [2026-02-02:07:57:04:INFO] Model objective : reg:squarederror
# [2026-02-02:07:57:04:INFO] No GPUs detected (normal if no gpus installed)
# [2026-02-02:07:57:04:INFO] Loading the model from /opt/ml/model/xgboost-model
# [2026-02-02:07:57:04:INFO] Model objective : reg:squarederror
# [2026-02-02:07:57:04:INFO] No GPUs detected (normal if no gpus installed)
# [2026-02-02:07:57:04:INFO] Loading the model from /opt/ml/model/xgboost-model
# [2026-02-02:07:57:04:INFO] Model objective : reg:squarederror
# [2026-02-02:07:57:04:INFO] No GPUs detected (normal if no gpus installed)
# [2026-02-02:07:57:04:INFO] No GPUs detected (normal if no gpus installed)
# [2026-02-02:07:57:04:INFO] Loading the model from /opt/ml/model/xgboost-model
# [2026-02-02:07:57:04:INFO] Model objective : reg:squarederror
# [2026-02-02:07:57:04:INFO] No GPUs detected (normal if no gpus installed)
# [2026-02-02:07:57:04:INFO] Loading the model from /opt/ml/model/xgboost-model
# [2026-02-02:07:57:04:INFO] Model objective : reg:squarederror
# [2026-02-02:07:57:04:INFO] No GPUs detected (normal if no gpus installed)
# [2026-02-02:07:57:04:INFO] Loading the model from /opt/ml/model/xgboost-model
# [2026-02-02:07:57:04:INFO] Model objective : reg:squarederror
# [2026-02-02:07:57:04:INFO] No GPUs detected (normal if no gpus installed)
# [2026-02-02:07:57:04:INFO] Loading the model from /opt/ml/model/xgboost-model
# [2026-02-02:07:57:04:INFO] Model objective : reg:squarederror
# [2026-02-02:07:57:04:INFO] Loading the model from /opt/ml/model/xgboost-model
# [2026-02-02:07:57:04:INFO] Model objective : reg:squarederror
# [2026-02-02:07:57:07:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [02/Feb/2026:07:57:07 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# [2026-02-02:07:57:07:INFO] No GPUs detected (normal if no gpus installed)
# [2026-02-02:07:57:07:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [02/Feb/2026:07:57:07 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# [2026-02-02:07:57:07:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [02/Feb/2026:07:57:07 +0000] "GET /execution-parameters HTTP/1.1" 200 84 "-" "Go-http-client/1.1"
# [2026-02-02:07:57:07:INFO] No GPUs detected (normal if no gpus installed)
# [2026-02-02:07:57:07:INFO] Determined delimiter of CSV input is ','
# /miniconda3/lib/python3.9/site-packages/xgboost/core.py:122: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# 169.254.255.130 - - [02/Feb/2026:07:57:07 +0000] "POST /invocations HTTP/1.1" 200 22050 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [02/Feb/2026:07:57:07 +0000] "GET /execution-parameters HTTP/1.1" 200 84 "-" "Go-http-client/1.1"
# [2026-02-02:07:57:07:INFO] No GPUs detected (normal if no gpus installed)
# [2026-02-02:07:57:07:INFO] Determined delimiter of CSV input is ','
# /miniconda3/lib/python3.9/site-packages/xgboost/core.py:122: UserWarning: ntree_limit is deprecated, use `iteration_range` or model slicing instead.
#   warnings.warn(
# 169.254.255.130 - - [02/Feb/2026:07:57:07 +0000] "POST /invocations HTTP/1.1" 200 22050 "-" "Go-http-client/1.1"
# 2026-02-02T07:57:07.311:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# Batch output: s3://nfci-forecasting-222634372778/nfci-xgboost-regression/batch-output/xgb-nfci-reg-2026-02-02-07-51-47

# %% [markdown]
# #### ### record the details after model training as metadata in s3

# %%
# import json
# import boto3

# s3 = boto3.client("s3", region_name=AWS_REGION)

# run_metadata = {
#     "training_job_name": job_name,
#     "training_prefix": prefix,
#     "bucket": bucket,
#     "timestamp": time.strftime("%Y-%m-%d %H:%M:%S")
# }

# metadata_key = f"{prefix}/run_metadata/latest.json"

# s3.put_object(
#     Bucket=bucket,
#     Key=metadata_key,
#     Body=json.dumps(run_metadata, indent=2).encode("utf-8"),
#     ContentType="application/json"
# )

# print("Saved run metadata to:")
# print(f"s3://{bucket}/{metadata_key}")
